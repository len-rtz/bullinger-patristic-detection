# %%
# !pip install locisimiles
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: locisimiles in /opt/anaconda3/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: accelerate>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from locisimiles) (1.7.0)
# Requirement already satisfied: chromadb<2.0.0,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from locisimiles) (1.5.1)
# Requirement already satisfied: numpy<3.0.0,>=1.24.0 in /opt/anaconda3/lib/python3.12/site-packages (from locisimiles) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from locisimiles) (2.2.2)
# Requirement already satisfied: sentence-transformers<6.0.0,>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from locisimiles) (5.2.3)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from locisimiles) (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from locisimiles) (4.52.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from accelerate>=0.20.0->locisimiles) (25.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from accelerate>=0.20.0->locisimiles) (5.9.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from accelerate>=0.20.0->locisimiles) (6.0.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from accelerate>=0.20.0->locisimiles) (0.32.3)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from accelerate>=0.20.0->locisimiles) (0.5.3)
# Requirement already satisfied: build>=1.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (1.4.0)
# Requirement already satisfied: pydantic>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (2.8.2)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=0.4.0->locisimiles) (0.41.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (8.2.3)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb<2.0.0,>=0.4.0->locisimiles) (4.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->locisimiles) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->locisimiles) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->locisimiles) (2023.3)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers<6.0.0,>=3.0.0->locisimiles) (1.5.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers<6.0.0,>=3.0.0->locisimiles) (1.12.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->locisimiles) (3.13.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->locisimiles) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->locisimiles) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->locisimiles) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->locisimiles) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0.0,>=2.0.0->locisimiles) (2024.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.30.0->locisimiles) (2024.9.11)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.30.0->locisimiles) (2.32.3)
# Requirement already satisfied: pyproject_hooks in /opt/anaconda3/lib/python3.12/site-packages (from build>=1.0.3->chromadb<2.0.0,>=0.4.0->locisimiles) (1.2.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=0.4.0->locisimiles) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=0.4.0->locisimiles) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=0.4.0->locisimiles) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=0.4.0->locisimiles) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.20.0->locisimiles) (1.1.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=0.4.0->locisimiles) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=0.4.0->locisimiles) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=0.4.0->locisimiles) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=0.4.0->locisimiles) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=0.4.0->locisimiles) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=0.4.0->locisimiles) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=0.4.0->locisimiles) (0.10)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=0.4.0->locisimiles) (25.12.19)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=0.4.0->locisimiles) (5.29.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=0.4.0->locisimiles) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=0.4.0->locisimiles) (0.60b1)
# Requirement already satisfied: backoff>=1.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=0.4.0->locisimiles) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb<2.0.0,>=0.4.0->locisimiles) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb<2.0.0,>=0.4.0->locisimiles) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.30.0->locisimiles) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=0.4.0->locisimiles) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=0.4.0->locisimiles) (2.15.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->locisimiles) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=0.4.0->locisimiles) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=0.4.0->locisimiles) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=0.4.0->locisimiles) (1.0.0)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=0.4.0->locisimiles) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=0.4.0->locisimiles) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=0.4.0->locisimiles) (16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.0.0->locisimiles) (2.1.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers<6.0.0,>=3.0.0->locisimiles) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers<6.0.0,>=3.0.0->locisimiles) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=0.4.0->locisimiles) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=0.4.0->locisimiles) (0.1.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=0.4.0->locisimiles) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=0.4.0->locisimiles) (3.3.1)

# %%
from locisimiles import ClassificationPipelineWithCandidategeneration
from locisimiles import Document

# Load documents
query = Document("../data/VD_bdc_chunks.csv")
source = Document("../data/VD_psc_chunks.csv")

# Define pipeline
pipeline = ClassificationPipelineWithCandidategeneration(
    classification_name="julian-schelb/PhilBerta-class-latin-intertext-v1",
    embedding_model_name="julian-schelb/SPhilBerta-emb-lat-intertext-v1",
    device="mps",  # or "cuda", "mps"
)

# Run pipeline
results = pipeline.run(query=query, source=source, top_k=100)
# Out:
# Embedding query segments: 100%|██████████| 19466/19466 [00:00<00:00, 2834646.45it/s]
# Embedding source segments: 100%|██████████| 46408/46408 [00:00<00:00, 455529.82it/s]
# Judging candidates:  27%|██▋       | 5241/19466 [10:53:49<51:31:42, 13.04s/it]

# %%
# use standalone utility functions
from locisimiles.pipeline import results_to_csv, results_to_json

results_to_csv(results, "results.csv")
results_to_json(results, "results.json")
